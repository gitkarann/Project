# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
with zipfile.ZipFile('/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation-20250509T070105Z-001.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/drive/MyDrive/Colab Notebooks')

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image, UnidentifiedImageError
from pathlib import Path
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
import matplotlib.pyplot as plt
import random
import shutil
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow import keras
from tensorflow.keras import layers, models, regularizers
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.applications import ResNet50, VGG16
import time

# %% [markdown]
# # **Data Understanding, Analysis, Visualization and Cleaning**

# %% [markdown]
# **What does the dataset represent? Provide a brief description.**
#
# Ans: The dataset represents a collection of medical images for brain tumor classification, specifically MRI scans categorized into four classes: glioma tumor, meningioma tumor, pituitary tumor, and normal (no tumor). The dataset is organized into two main directories: train and test, each containing subdirectories for the four classes. This dataset is likely used for training and evaluating a machine learning model to classify brain tumors based on MRI images.

# %% [markdown]
# **How many total images are in the dataset?**

# %%
base_path = "/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation"
splits = ["train", "test"]
classes = ["glioma_tumor", "meningioma_tumor", "normal", "pituitary_tumor"]

total_images = 0
for split in splits:
    for cls in classes:
        folder = f"{base_path}/{split}/{cls}"
        num_images = len(os.listdir(folder))
        total_images += num_images
print(f"Total images: {total_images}")
# Out:
# Total images: 3096

# %% [markdown]
# **What is the distribution of images across different classes?**

# %%
for split in splits:
    print(f"\n{split} distribution:")
    for cls in classes:
        folder = f"{base_path}/{split}/{cls}"
        num_images = len(os.listdir(folder))
        print(f"{cls}: {num_images} images")
# Out:
# train distribution:
# glioma_tumor: 720 images
# meningioma_tumor: 730 images
# normal: 350 images
# pituitary_tumor: 675 images
#
# test distribution:
# glioma_tumor: 181 images
# meningioma_tumor: 183 images
# normal: 88 images
# pituitary_tumor: 169 images

# %% [markdown]
# **Finding and deleting corrupt images**

# %%
from PIL import Image
import os

def validate_images(directory):
    corrupt_count = 0

    for root, _, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                with Image.open(file_path) as img:
                    img.verify()  # Will raise an exception if the image is bad
            except Exception as e:
                print(f"Corrupt or invalid image: {file_path} ({e})")
                corrupt_count += 1

    print(f"\nTotal number of corrupted or invalid images: {corrupt_count}")

# Call the function
validate_images('/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train')
# Out:
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_2.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_2.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_560.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_560.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_406.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_406.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_744.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_744.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_107.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_107.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_737.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_737.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_839.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_839.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_66.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_66.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_276.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_276.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_278.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_278.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_132.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_132.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_166.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_166.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_263.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_263.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_90.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_90.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_54.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_54.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_179.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_179.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_440.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_440.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_680.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_680.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_323.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_323.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_154.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_154.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_765.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_765.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_550.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_550.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_741.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_741.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_757.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_757.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_160.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_160.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_397.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_397.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_170.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_170.jpg')
# Corrupt or invalid image: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_703.jpg (cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_703.jpg')
#
# Total number of corrupted or invalid images: 28

# %%
def remove_corrupt_images(directory):
    removed = 0
    for root, _, files in os.walk(directory):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                file_path = os.path.join(root, file)
                try:
                    img = Image.open(file_path)
                    img.verify()  # Verify that image is not corrupted
                except Exception as e:
                    print(f"Removing corrupt file: {file_path} - Reason: {e}")
                    os.remove(file_path)
                    removed += 1
    print(f"Removed {removed} corrupt images.")

remove_corrupt_images("/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train")
# Out:
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_2.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_2.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_560.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_560.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_406.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_406.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_744.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_744.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_107.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_107.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_737.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_737.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_839.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor/G_839.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_66.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_66.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_276.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_276.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_278.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_278.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_132.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_132.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_166.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_166.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_263.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_263.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_90.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal/N_90.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_54.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_54.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_179.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_179.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_440.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_440.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_680.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_680.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_323.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_323.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_154.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_154.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_765.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor/M_765.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_550.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_550.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_741.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_741.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_757.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_757.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_160.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_160.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_397.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_397.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_170.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_170.jpg'
# Removing corrupt file: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_703.jpg - Reason: cannot identify image file '/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor/P_703.jpg'
# Removed 28 corrupt images.

# %%
for split in splits:
    print(f"\n{split} class distribution after removing corrupt images:")
    for cls in classes:
        folder = f"{base_path}/{split}/{cls}"
        num_images = len(os.listdir(folder))
        print(f"{cls}: {num_images} images")
# Out:
# train class distribution after removing corrupt images:
# glioma_tumor: 713 images
# meningioma_tumor: 723 images
# normal: 343 images
# pituitary_tumor: 668 images
#
# test class distribution after removing corrupt images:
# glioma_tumor: 181 images
# meningioma_tumor: 183 images
# normal: 88 images
# pituitary_tumor: 169 images

# %% [markdown]
# **How is the dataset split into training and validation sets? Justify your choice.**
#
# Ans: The dataset is split into training and test sets, with approximately 80% of the data allocated to training and 20% to testing for each class. Justification: This 80/20 split ensures a sufficient number of images for training robust models while maintaining a representative test set for evaluation. The proportional split across classes preserves the class distribution, avoiding bias and ensuring balanced evaluation. No separate validation set is explicitly mentioned, suggesting the test set may serve as the validation set, or a further split (e.g., 10% of training for validation) could be applied if needed.

# %% [markdown]
# **What preprocessing techniques (e.g., resizing, normalization) were applied?**
#
# Ans: Likely Applied Preprocessing Resizing: Images resized to 224x224 or 256x256. Normalization: Pixel values scaled to [0, 1] or standardized (z-score). Grayscale Conversion: Multi-channel MRIs converted to single-channel. Data Augmentation: Random rotations, flips, translations, zoom. Contrast Adjustment: Histogram equalization or CLAHE. Cropping: Non-brain areas removed. Class Balancing: Oversampling/undersampling or class weights. Noise Reduction: Gaussian blur or median filtering.

# %% [markdown]
# **What data generators, if any, were used for preprocessing and augmentation?**
#
# Ans: Preprocessing: Resizing to 224x224 or 256x256, normalization (e.g., [0, 1] or z-score). Augmentations: Random rotations (±10–30°), horizontal flips, zoom (0.8–1.2x), translations.

# %%
train_dir = "/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train"
test_dir = "/content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/test"

target_count = 750  # Minimum images per class

# Augmentation configuration
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode='nearest'
)

# Function to augment images for a class
def augment_images(class_name, current_count, images_needed, class_dir, save_dir):
    os.makedirs(save_dir, exist_ok=True)
    img_count = 0
    valid_images = [f for f in os.listdir(class_dir) if f.endswith(('.jpg', '.jpeg', '.png'))]

    if not valid_images:
        print(f"No valid images found for {class_name}")
        return

    # Cycle through images multiple times if needed
    while img_count < images_needed:
        for img_name in valid_images:
            if img_count >= images_needed:
                break
            img_path = os.path.join(class_dir, img_name)
            try:
                img = load_img(img_path, target_size=(224, 224))
                x = img_to_array(img)
                x = x.reshape((1,) + x.shape)

                # Generate one augmented image per iteration
                for batch in datagen.flow(x, batch_size=1, save_to_dir=save_dir, save_prefix=f'aug_{class_name}', save_format='jpg'):
                    img_count += 1
                    break  # Generate one image and move to next
            except (UnidentifiedImageError, Exception) as e:
                print(f"Skipping {img_path}: {e}")
                continue

# Process each class
for class_name in classes:
    class_dir = os.path.join(train_dir, class_name)
    aug_dir = os.path.join(train_dir, f'augmented_{class_name}')
    current_count = len([f for f in os.listdir(class_dir) if f.endswith(('.jpg', '.jpeg', '.png'))])
    images_needed = max(0, target_count - current_count)

    print(f'{class_name}: Current={current_count}, Needed={images_needed}')

    if images_needed > 0:
        augment_images(class_name, current_count, images_needed, class_dir, aug_dir)

# Count final images per class (including augmented)
print("\nFinal image counts per class:")
for class_name in classes:
    class_dir = os.path.join(train_dir, class_name)
    aug_dir = os.path.join(train_dir, f'augmented_{class_name}')
    class_count = len([f for f in os.listdir(class_dir) if f.endswith(('.jpg', '.jpeg', '.png'))])
    aug_count = len([f for f in os.listdir(aug_dir) if f.endswith(('.jpg', '.jpeg', '.png'))]) if os.path.exists(aug_dir) else 0
    total_count = class_count + aug_count
    print(f'{class_name}: {total_count} images')

print("Augmentation complete.")
# Out:
# glioma_tumor: Current=713, Needed=37
# meningioma_tumor: Current=723, Needed=27
# normal: Current=343, Needed=407
# pituitary_tumor: Current=668, Needed=82
#
# Final image counts per class:
# glioma_tumor: 750 images
# meningioma_tumor: 750 images
# normal: 739 images
# pituitary_tumor: 748 images
# Augmentation complete.

# %%
# Function to merge augmented images into the main class folder
def merge_augmented_images():
    for class_name in classes:
        # Define paths for the class folder and augmented folder
        class_dir = os.path.join(train_dir, class_name)
        aug_dir = os.path.join(train_dir, f'augmented_{class_name}')

        # Check if the augmented directory exists
        if not os.path.exists(aug_dir):
            print(f"No augmented folder found for {class_name}, skipping.")
            continue

        # Get list of augmented images
        aug_images = [f for f in os.listdir(aug_dir) if f.endswith(('.jpg', '.jpeg', '.png'))]

        # Move each augmented image to the main class folder
        for img_name in aug_images:
            src_path = os.path.join(aug_dir, img_name)
            dst_path = os.path.join(class_dir, img_name)

            # If a file with the same name exists, append a suffix to avoid overwriting
            base, ext = os.path.splitext(img_name)
            counter = 1
            while os.path.exists(dst_path):
                new_img_name = f"{base}_{counter}{ext}"
                dst_path = os.path.join(class_dir, new_img_name)
                counter += 1

            shutil.move(src_path, dst_path)
            print(f"Moved {img_name} to {class_dir}")

        # Remove the now-empty augmented folder
        shutil.rmtree(aug_dir)
        print(f"Removed empty augmented folder: {aug_dir}")

    print("\nFinal image counts per class after merging:")
    for class_name in classes:
        class_dir = os.path.join(train_dir, class_name)
        class_count = len([f for f in os.listdir(class_dir) if f.endswith(('.jpg', '.jpeg', '.png'))])
        print(f'{class_name}: {class_count} images')

    print("Merging complete.")

# Run the merging process
merge_augmented_images()
# Out:
# Moved aug_glioma_tumor_0_9605.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_9922.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_3341.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_9621.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_6075.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_2052.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_2264.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_7133.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_1524.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_7108.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_9262.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_3315.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_2675.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_8676.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_7243.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_765.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_6968.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_6494.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_8045.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_2991.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_751.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_2554.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_5276.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_1939.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_1188.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_6315.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_561.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_3432.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_5869.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_761.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_2556.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_9734.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_4741.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_3314.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_6799.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_8984.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Moved aug_glioma_tumor_0_9748.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/glioma_tumor
# Removed empty augmented folder: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/augmented_glioma_tumor
# Moved aug_meningioma_tumor_0_9349.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_4975.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_2838.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_8111.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_2527.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_3741.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_7773.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_3173.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_8978.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_3260.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_816.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_8489.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_56.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_590.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_2418.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_6635.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_2822.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_8703.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_8256.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_7818.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_8109.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_5477.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_2796.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_8563.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_8930.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_7889.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Moved aug_meningioma_tumor_0_4618.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/meningioma_tumor
# Removed empty augmented folder: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/augmented_meningioma_tumor
# Moved aug_normal_0_2584.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6092.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_377.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8929.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4512.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1600.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6765.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5740.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2765.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2718.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5116.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7654.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5765.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8035.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2430.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9447.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6933.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9961.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_28.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2856.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7000.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5839.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9532.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6535.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6529.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5685.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2170.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7209.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3023.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1078.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_683.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8141.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5282.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7407.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7132.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3222.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1289.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2201.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5783.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6614.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1191.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9989.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9950.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3062.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5730.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6900.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3638.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_736.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3972.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7232.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1627.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2789.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4053.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3668.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8688.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7375.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5998.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2131.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5743.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6289.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2317.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4838.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1701.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9540.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5564.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5518.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7162.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4396.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3086.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3938.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7732.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7018.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8819.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3558.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5381.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5900.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8678.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7168.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4074.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5173.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3781.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3848.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_887.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8820.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_537.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8446.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7526.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8203.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9201.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2128.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1422.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9727.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6720.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7355.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7363.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1256.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6457.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1839.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3249.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4381.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_305.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4855.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2305.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1431.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3532.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6834.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8263.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3835.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5408.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2549.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9175.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8140.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_733.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3609.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3888.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1498.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8982.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8773.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6945.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5000.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_553.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1377.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5251.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_73.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2499.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4792.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8340.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9396.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3200.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5760.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8873.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_100.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9320.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_497.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3278.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9729.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5151.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5232.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3399.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2462.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2010.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_758.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8235.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5041.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5485.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1216.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_669.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9232.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6248.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2878.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8218.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1059.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6534.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4683.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8383.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4663.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8995.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2150.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9074.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7938.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2861.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1660.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3406.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3480.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3540.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6235.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2525.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3697.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2301.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8249.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7023.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6191.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3857.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1896.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4968.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5617.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4081.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_684.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5111.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4821.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2446.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5473.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5580.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6380.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8272.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4713.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8385.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4544.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2581.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7392.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6820.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5199.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_471.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8975.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1841.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4819.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6722.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1639.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6905.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6973.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_90.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_507.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_768.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3178.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2289.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4222.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3276.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1485.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2829.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3386.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2160.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4677.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_365.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1653.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7824.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8757.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6829.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4594.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9336.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7259.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6188.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4121.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7905.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6214.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8308.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1974.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6225.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2582.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8630.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9138.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8065.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4084.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5671.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9150.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2551.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4209.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8244.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8379.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2877.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5340.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9086.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5696.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3847.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6218.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7509.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8657.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5877.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3737.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9722.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6989.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6996.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9002.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3920.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2405.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4379.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4431.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9611.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5929.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4903.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4245.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1879.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9609.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8204.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8567.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1277.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1597.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_631.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2488.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_859.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5904.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1069.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_894.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9872.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2520.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2141.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_531.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5989.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8867.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2987.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1840.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_609.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1020.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_866.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4779.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2980.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5203.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1813.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6023.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9204.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3166.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6441.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5729.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8795.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6552.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8520.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4583.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1060.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2037.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4390.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6988.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5644.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6807.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2906.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5226.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2298.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2456.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2118.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_741.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9635.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3825.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1495.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1142.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7571.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3493.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7737.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4170.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5798.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_936.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8782.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4291.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7763.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_548.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1907.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3810.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4856.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7233.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2940.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4789.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9879.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1472.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8399.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7182.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_871.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3001.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2474.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1304.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7019.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9725.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5482.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5016.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4271.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3646.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1239.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2806.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4324.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3950.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6745.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9670.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8423.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9382.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4359.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5055.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4949.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8786.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6297.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5525.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7311.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7515.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7118.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6781.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_309.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7965.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6859.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5357.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8445.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_94.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3190.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_4578.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_2691.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_179.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3833.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9456.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9400.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3614.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3991.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5002.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_341.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8013.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7285.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_352.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9303.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_411.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_1318.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9350.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5505.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3841.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3685.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_776.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6016.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_3818.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_5073.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_7417.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_8588.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_9009.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Moved aug_normal_0_6072.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/normal
# Removed empty augmented folder: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/augmented_normal
# Moved aug_pituitary_tumor_0_3425.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_5499.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_7366.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_1866.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_250.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_8221.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_3488.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_1848.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_9047.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_8822.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_147.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_7308.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_2491.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_1280.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_2275.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_2379.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_4508.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_9582.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_1552.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_7873.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_8386.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_6003.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_3920.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_3815.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_2200.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_9372.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_7343.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_5662.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_8356.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_1604.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_5236.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_9438.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_1263.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_348.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_5263.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_7316.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_1775.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_3271.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_596.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_144.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_3338.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_2134.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_5581.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_1541.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_9383.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_1057.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_3924.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_7449.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_486.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_9204.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_7474.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_1972.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_9770.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_103.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_1817.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_3101.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_2494.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_9459.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_420.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_4741.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_4340.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_4661.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_3881.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_6056.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_558.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_3753.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_9135.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_6376.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_5040.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_1623.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_4977.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_4306.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_4941.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_1891.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_3124.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_1122.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_4547.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_5095.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_8361.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Moved aug_pituitary_tumor_0_1040.jpg to /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/pituitary_tumor
# Removed empty augmented folder: /content/drive/MyDrive/Colab Notebooks/Brain Tumor Classifcation/train/augmented_pituitary_tumor
#
# Final image counts per class after merging:
# glioma_tumor: 750 images
# meningioma_tumor: 750 images
# normal: 739 images
# pituitary_tumor: 748 images
# Merging complete.

# %%
num_images_per_class = 3  # Adjust as needed
# Set up plot
plt.figure(figsize=(15, 12))
img_index = 1

for class_name in classes:
    class_dir = os.path.join(train_dir, class_name)
    images = [f for f in os.listdir(class_dir) if f.startswith('aug_') and f.endswith(('.jpg', '.jpeg', '.png'))]

    if len(images) == 0:
        print(f"No augmented images found for {class_name}")
        continue

    selected_images = random.sample(images, min(num_images_per_class, len(images)))

    for img_name in selected_images:
        try:
            img_path = os.path.join(class_dir, img_name)
            img = load_img(img_path, target_size=(224, 224))
            plt.subplot(len(classes), num_images_per_class, img_index)
            plt.imshow(img)
            plt.title(f"{class_name}")
            plt.axis('off')
            img_index += 1
        except UnidentifiedImageError:
            print(f"Could not load image {img_name}, skipping.")
            continue

plt.tight_layout()
plt.suptitle("Augmented Images (agu_*)", fontsize=16, y=1.02)
plt.show()

# %% [markdown]
# # **Design, Train, and Evaluate a Baseline Model**

# %% [markdown]
# **Prepare training and validation generators**

# %%
# Image and training parameters
IMG_SIZE = (128, 128)
BATCH_SIZE = 32
EPOCHS = 20

# Prepare training and validation generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # 20% of training data used for validation
)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='sparse',  # sparse because we'll use sparse_categorical_crossentropy
    subset='training',
    shuffle=True
)

val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='sparse',
    subset='validation',
    shuffle=False
)

# Test data generator (only rescaling)
test_datagen = ImageDataGenerator(rescale=1./255)

# Test data loader
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 2391 images belonging to 4 classes.
# Found 596 images belonging to 4 classes.
# Found 621 images belonging to 4 classes.

# %% [markdown]
# **Model Architecture**

# %%
# # Define the Base CNN model
# base_model = Sequential([
#     # First Convolutional Block
#     Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
#     MaxPooling2D((2, 2)),

#     # Second Convolutional Block
#     Conv2D(64, (3, 3), activation='relu'),
#     MaxPooling2D((2, 2)),

# Define a simple Baseline CNN model
model = keras.Sequential([
    # First Input Layer
    layers.Conv2D(32, (3, 3),padding="same", strides=1, activation="relu", input_shape=(128, 128, 3)),
    layers.MaxPooling2D((2, 2),strides=2),

    # Second Input Layer
    layers.Conv2D(64, (3, 3),padding="same", strides=1, activation="relu"),
    layers.MaxPooling2D((2, 2),strides=2),

    # Third Input Layer
    layers.Conv2D(128, (3, 3),padding="same", strides=1, activation="relu"),
    layers.MaxPooling2D((2, 2),strides=2),

    # Flatten to transition to fully connected layers
    layers.Flatten(),

    # First Fully Connected Layer
    layers.Dense(128, activation="relu"),

    # Second Fully Connected Layer
    layers.Dense(64, activation="relu"),

    # Third Fully Connected Layer
    layers.Dense(32, activation="relu"),

    # Output Layer
    layers.Dense(4, activation="softmax")  # 4 classes: glioma, meningioma, normal, pituitary

])

# Compile Model
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Print Model Summary
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     4,194,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,298,148 (16.40 MB)
#  Trainable params: 4,298,148 (16.40 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# # Train the model
# basemodel_history = model.fit(
#     train_generator,
#     validation_data=val_generator,
#     epochs=EPOCHS
# )

# Compute model complexity
baseline_params = model.count_params()
print(f"\nBaseline Model Parameters: {baseline_params:,}")

# Train with timing
start_time = time.time()
basemodel_history = model.fit(train_generator, validation_data=val_generator, epochs=EPOCHS)
end_time = time.time()

baseline_training_time = end_time - start_time
print(f"\nBaseline Model Training Time: {baseline_training_time:.2f} seconds")
# Out:
# Baseline Model Parameters: 4,298,148
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 204ms/step - accuracy: 0.3733 - loss: 1.3078 - val_accuracy: 0.5017 - val_loss: 1.2425
# Epoch 2/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 146ms/step - accuracy: 0.5977 - loss: 0.9490 - val_accuracy: 0.5386 - val_loss: 1.2175
# Epoch 3/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - accuracy: 0.6855 - loss: 0.7906 - val_accuracy: 0.6393 - val_loss: 0.8079
# Epoch 4/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 152ms/step - accuracy: 0.7967 - loss: 0.5031 - val_accuracy: 0.6510 - val_loss: 0.8213
# Epoch 5/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 146ms/step - accuracy: 0.8735 - loss: 0.3433 - val_accuracy: 0.7668 - val_loss: 0.6786
# Epoch 6/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 144ms/step - accuracy: 0.9237 - loss: 0.2153 - val_accuracy: 0.7819 - val_loss: 0.6015
# Epoch 7/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 0.9529 - loss: 0.1298 - val_accuracy: 0.7550 - val_loss: 0.8355
# Epoch 8/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.9781 - loss: 0.0743 - val_accuracy: 0.7735 - val_loss: 1.1784
# Epoch 9/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 147ms/step - accuracy: 0.9762 - loss: 0.0565 - val_accuracy: 0.8037 - val_loss: 1.1884
# Epoch 10/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 144ms/step - accuracy: 0.9880 - loss: 0.0426 - val_accuracy: 0.7987 - val_loss: 1.0160
# Epoch 11/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9969 - loss: 0.0115 - val_accuracy: 0.7836 - val_loss: 1.1418
# Epoch 12/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 141ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.7936 - val_loss: 1.1828
# Epoch 13/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 142ms/step - accuracy: 1.0000 - loss: 9.4700e-04 - val_accuracy: 0.7970 - val_loss: 1.2857
# Epoch 14/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 1.0000 - loss: 3.5047e-04 - val_accuracy: 0.7970 - val_loss: 1.3312
# Epoch 15/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 1.0000 - loss: 2.4633e-04 - val_accuracy: 0.7953 - val_loss: 1.3414
# Epoch 16/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - accuracy: 1.0000 - loss: 2.0561e-04 - val_accuracy: 0.7953 - val_loss: 1.3682
# Epoch 17/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 144ms/step - accuracy: 1.0000 - loss: 1.7702e-04 - val_accuracy: 0.7953 - val_loss: 1.3697
# Epoch 18/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 1.0000 - loss: 1.3692e-04 - val_accuracy: 0.7970 - val_loss: 1.3868
# Epoch 19/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 1.0000 - loss: 1.1272e-04 - val_accuracy: 0.7970 - val_loss: 1.4235
# Epoch 20/20
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 1.0000 - loss: 1.0783e-04 - val_accuracy: 0.7953 - val_loss: 1.4243
#
# Baseline Model Training Time: 256.17 seconds

# %%
# Plot training vs validation loss
plt.figure(figsize=(12, 4))

# Plotting training and validation loss
plt.subplot(1, 2, 1)
plt.plot(basemodel_history.history['loss'], label='Training Loss')
plt.plot(basemodel_history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss for Baseline Model')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plotting Training and Validation Accuracy
plt.subplot(1, 2, 2)
plt.plot(basemodel_history.history['accuracy'], label='Training Accuracy')
plt.plot(basemodel_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy for Baseline Model')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"\nTest Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - accuracy: 0.8269 - loss: 1.3952
#
# Test Accuracy: 0.8374
# Test Loss: 1.2824

# %%
# Get true labels
true_labels = test_generator.classes

# Get predicted probabilities and convert to class labels
pred_probs = model.predict(test_generator)
pred_labels = np.argmax(pred_probs, axis=1)

# Calculate metrics
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, average='weighted')
recall = recall_score(true_labels, pred_labels, average='weighted')
f1 = f1_score(true_labels, pred_labels, average='weighted')

print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")

class_labels = list(test_generator.class_indices.keys())
basemodel_report = classification_report(true_labels, pred_labels, target_names=class_labels)
print("\nClassification Report of Baseline Model:\n")
print(basemodel_report)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step
# Accuracy:  0.8374
# Precision: 0.8383
# Recall:    0.8374
# F1 Score:  0.8369
#
# Classification Report of Baseline Model:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.85      0.86      0.85       181
# meningioma_tumor       0.82      0.75      0.78       183
#           normal       0.76      0.86      0.81        88
#  pituitary_tumor       0.89      0.89      0.89       169
#
#         accuracy                           0.84       621
#        macro avg       0.83      0.84      0.83       621
#     weighted avg       0.84      0.84      0.84       621

# %%
# Define class labels
class_labels = list(test_generator.class_indices.keys())

# Sample a few test images
sample_images = []
true_classes = []
for class_name in class_labels:
    class_dir = os.path.join(test_dir, class_name)
    images = os.listdir(class_dir)[:2]  # 2 images per class
    for img_name in images:
        sample_images.append(os.path.join(class_dir, img_name))
        true_classes.append(class_name)

# Plot predictions
plt.figure(figsize=(15, 10))

for i, img_path in enumerate(sample_images):
    # Load image
    img = load_img(img_path, target_size=(128, 128))
    img_array = img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    # Predict
    predictions = model.predict(img_array)
    predicted_class = class_labels[np.argmax(predictions)]
    true_class = true_classes[i]

    # Color: green if correct, red otherwise
    color = "green" if predicted_class == true_class else "red"

    # Plot
    plt.subplot(3, 4, i + 1)
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"True: {true_class}\nPred: {predicted_class}", color=color)

plt.tight_layout()
plt.suptitle("Prediction of different Classes with Base Model", fontsize=16, y=1.02)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 743ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %% [markdown]
# # **Design, Train , and Evaluate Deeper Architecture with Regularization Layer**

# %% [markdown]
# ### **Deeper Model Architecture with Adam Optimizer**

# %%
# Build deeper, regularized model
deeper1_model = keras.Sequential([
    # Block 1
    layers.Conv2D(32, (3, 3), padding="same", activation="relu", input_shape=(128, 128, 3)),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3, 3), padding="same", activation="relu"),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Block 2
    layers.Conv2D(64, (3, 3), padding="same", activation="relu"),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3, 3), padding="same", activation="relu"),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.3),

    # Block 3
    layers.Conv2D(128, (3, 3), padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3, 3), padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    # Block 4
    layers.Conv2D(256, (3, 3), padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Conv2D(256, (3, 3), padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.5),

    # Block 5
    layers.Conv2D(512, (3, 3), padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Conv2D(256, (3, 3), padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.6),

    # Fully Connected Layers
    layers.Flatten(),

    # First FCN
    layers.Dense(512, activation="relu"),
    layers.Dropout(0.5),

    # Second FCN
    layers.Dense(256, activation="relu"),
    layers.Dropout(0.25),

    # Third FCN
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.2),

    #Fourth FCN
    layers.Dense(64, activation="relu"),

    #Output Layer
    layers.Dense(4, activation="softmax")  # 4 classes
])

# Compile the model
deeper1_model.compile(
    optimizer=keras.optimizers.Adam(),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# Show model architecture
deeper1_model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 128, 128, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 64, 64, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 8, 8, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 8, 8, 256)      │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,806,692 (22.15 MB)
#  Trainable params: 5,804,708 (22.14 MB)
#  Non-trainable params: 1,984 (7.75 KB)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Compute model complexity
deeper1_params = deeper1_model.count_params()
print(f"\nDeeper Model Parameters: {deeper1_params:,}")

# Train with timing
start_time = time.time()
deeper1_history = deeper1_model.fit(
    train_generator,
    epochs=50,
    validation_data=val_generator,
    callbacks=[early_stop]
)
end_time = time.time()

deeper1_training_time = end_time - start_time
print(f"\nDeeper Model Training Time: {deeper1_training_time:.2f} seconds")
# Out:
# Deeper Model Parameters: 5,806,692
# Epoch 1/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 49s 372ms/step - accuracy: 0.2929 - loss: 3.7677 - val_accuracy: 0.2634 - val_loss: 2.8202
# Epoch 2/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 0.3525 - loss: 2.7958 - val_accuracy: 0.3205 - val_loss: 2.7564
# Epoch 3/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.3841 - loss: 2.6428 - val_accuracy: 0.2466 - val_loss: 2.6987
# Epoch 4/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 140ms/step - accuracy: 0.4421 - loss: 2.4992 - val_accuracy: 0.3574 - val_loss: 2.6149
# Epoch 5/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 0.5128 - loss: 2.3050 - val_accuracy: 0.2366 - val_loss: 3.1441
# Epoch 6/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 141ms/step - accuracy: 0.5882 - loss: 2.0939 - val_accuracy: 0.3138 - val_loss: 4.9579
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.6510 - loss: 1.9544 - val_accuracy: 0.3574 - val_loss: 4.6844
# Epoch 8/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 151ms/step - accuracy: 0.6831 - loss: 1.8349 - val_accuracy: 0.6376 - val_loss: 2.2380
# Epoch 9/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 144ms/step - accuracy: 0.7097 - loss: 1.6985 - val_accuracy: 0.5235 - val_loss: 2.0429
# Epoch 10/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.7164 - loss: 1.6014 - val_accuracy: 0.5151 - val_loss: 2.2020
# Epoch 11/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - accuracy: 0.7465 - loss: 1.4645 - val_accuracy: 0.6829 - val_loss: 1.7098
# Epoch 12/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 20s 143ms/step - accuracy: 0.7348 - loss: 1.4010 - val_accuracy: 0.4983 - val_loss: 2.8799
# Epoch 13/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.7603 - loss: 1.3035 - val_accuracy: 0.5604 - val_loss: 2.0760
# Epoch 14/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 0.7751 - loss: 1.2070 - val_accuracy: 0.5990 - val_loss: 2.6402
# Epoch 15/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 144ms/step - accuracy: 0.7725 - loss: 1.2001 - val_accuracy: 0.5235 - val_loss: 1.7573
# Epoch 16/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 20s 143ms/step - accuracy: 0.7872 - loss: 1.1259 - val_accuracy: 0.7718 - val_loss: 1.2002
# Epoch 17/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 20s 144ms/step - accuracy: 0.8104 - loss: 1.0254 - val_accuracy: 0.5319 - val_loss: 2.1155
# Epoch 18/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 0.8140 - loss: 0.9748 - val_accuracy: 0.5537 - val_loss: 1.7270
# Epoch 19/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 20s 141ms/step - accuracy: 0.8299 - loss: 0.9122 - val_accuracy: 0.5923 - val_loss: 1.2854
# Epoch 20/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 152ms/step - accuracy: 0.7689 - loss: 0.9756 - val_accuracy: 0.7349 - val_loss: 1.0564
# Epoch 21/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - accuracy: 0.8270 - loss: 0.8728 - val_accuracy: 0.6594 - val_loss: 1.2081
# Epoch 22/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 0.8302 - loss: 0.8525 - val_accuracy: 0.5621 - val_loss: 1.9485
# Epoch 23/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 145ms/step - accuracy: 0.8237 - loss: 0.8877 - val_accuracy: 0.7483 - val_loss: 0.9574
# Epoch 24/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.8144 - loss: 0.8742 - val_accuracy: 0.7668 - val_loss: 0.9686
# Epoch 25/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - accuracy: 0.8275 - loss: 0.8409 - val_accuracy: 0.5923 - val_loss: 1.6685
# Epoch 26/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.8443 - loss: 0.8389 - val_accuracy: 0.3641 - val_loss: 5.8377
# Epoch 27/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8323 - loss: 0.7991 - val_accuracy: 0.7114 - val_loss: 1.4152
# Epoch 28/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 0.8630 - loss: 0.7445 - val_accuracy: 0.3926 - val_loss: 3.2868
#
# Deeper Model Training Time: 408.97 seconds

# %%
# Plot training vs validation loss
plt.figure(figsize=(12, 4))

# Plotting training and validation loss
plt.subplot(1, 2, 1)
plt.plot(deeper1_history.history['loss'], label='Training Loss')
plt.plot(deeper1_history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss for Deeper Model with Adam')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plotting Training and Validation Accuracy
plt.subplot(1, 2, 2)
plt.plot(deeper1_history.history['accuracy'], label='Training Accuracy')
plt.plot(deeper1_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy for Deeper Model with Adam')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Evaluate the model on the test data
test_loss, test_accuracy = deeper1_model.evaluate(test_generator)
print(f"\nTest Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.5995 - loss: 1.2128
#
# Test Accuracy: 0.7295
# Test Loss: 1.0480

# %%
# Get true labels
true_labels = test_generator.classes

# Get predicted probabilities and convert to class labels
pred_probs = deeper1_model.predict(test_generator)
pred_labels = np.argmax(pred_probs, axis=1)

# Calculate metrics
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, average='weighted')
recall = recall_score(true_labels, pred_labels, average='weighted')
f1 = f1_score(true_labels, pred_labels, average='weighted')

print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")

class_labels = list(test_generator.class_indices.keys())
deep1_report = classification_report(true_labels, pred_labels, target_names=class_labels)
print("\nClassification Report of Deeper Model with Adam Optimizer:\n")
print(deep1_report)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step
# Accuracy:  0.7295
# Precision: 0.7777
# Recall:    0.7295
# F1 Score:  0.7195
#
# Classification Report of Deeper Model with Adam Optimizer:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       1.00      0.49      0.65       181
# meningioma_tumor       0.64      0.65      0.64       183
#           normal       0.61      0.97      0.75        88
#  pituitary_tumor       0.78      0.95      0.86       169
#
#         accuracy                           0.73       621
#        macro avg       0.76      0.76      0.73       621
#     weighted avg       0.78      0.73      0.72       621

# %%
# Define class labels
class_labels = list(test_generator.class_indices.keys())

# Sample a few test images
sample_images = []
true_classes = []
for class_name in class_labels:
    class_dir = os.path.join(test_dir, class_name)
    images = os.listdir(class_dir)[:2]  # 2 images per class
    for img_name in images:
        sample_images.append(os.path.join(class_dir, img_name))
        true_classes.append(class_name)

# Plot predictions
plt.figure(figsize=(15, 10))

for i, img_path in enumerate(sample_images):
    # Load image
    img = load_img(img_path, target_size=(128, 128))
    img_array = img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    # Predict
    predictions = deeper1_model.predict(img_array)
    predicted_class = class_labels[np.argmax(predictions)]
    true_class = true_classes[i]

    # Color: green if correct, red otherwise
    color = "green" if predicted_class == true_class else "red"

    # Plot
    plt.subplot(3, 4, i + 1)
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"True: {true_class}\nPred: {predicted_class}", color=color)

plt.tight_layout()
plt.suptitle("Prediction of different Classes with Deeper Model and Adamn Optimizer", fontsize=16, y=1.02)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %% [markdown]
# # **Comparision and Analysis**

# %% [markdown]
# ### **Baseline vs. Deeper Model Performance**

# %%
# Get true labels
true_labels = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# Function to evaluate a model
def evaluate_model(model, model_name):
    pred_probs = model.predict(test_generator)
    pred_labels = np.argmax(pred_probs, axis=1)

    accuracy = accuracy_score(true_labels, pred_labels)
    precision = precision_score(true_labels, pred_labels, average='weighted')
    recall = recall_score(true_labels, pred_labels, average='weighted')
    f1 = f1_score(true_labels, pred_labels, average='weighted')

    report_dict = classification_report(true_labels, pred_labels, target_names=class_labels, output_dict=True)

    print(f"\nClassification Report of {model_name}:\n")
    print(classification_report(true_labels, pred_labels, target_names=class_labels))

    return {
        "Model": model_name,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1 Score": f1,
        "Report": report_dict
    }

# Evaluate baseline and deeper (Adam) models
baseline_results = evaluate_model(model, "Baseline Model")
adam_results = evaluate_model(deeper1_model, "Deeper Model with Adam Optimizer")

# Compare overall metrics
overall_comparison = pd.DataFrame([
    {"Metric": "Accuracy", "Baseline": baseline_results["Accuracy"], "Adam": adam_results["Accuracy"]},
    {"Metric": "Precision", "Baseline": baseline_results["Precision"], "Adam": adam_results["Precision"]},
    {"Metric": "Recall", "Baseline": baseline_results["Recall"], "Adam": adam_results["Recall"]},
    {"Metric": "F1 Score", "Baseline": baseline_results["F1 Score"], "Adam": adam_results["F1 Score"]}
])

print("\nOverall Performance Comparison:\n")
print(overall_comparison)

# Class-wise comparison
class_comparison = pd.DataFrame({
    cls: {
        "Baseline Precision": baseline_results["Report"][cls]["precision"],
        "Adam Precision": adam_results["Report"][cls]["precision"],
        "Baseline Recall": baseline_results["Report"][cls]["recall"],
        "Adam Recall": adam_results["Report"][cls]["recall"],
        "Baseline F1": baseline_results["Report"][cls]["f1-score"],
        "Adam F1": adam_results["Report"][cls]["f1-score"]
    }
    for cls in class_labels
}).T

print("\nClass-wise Metrics Comparison:\n")
print(class_comparison)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step
#
# Classification Report of Baseline Model:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.85      0.86      0.85       181
# meningioma_tumor       0.82      0.75      0.78       183
#           normal       0.76      0.86      0.81        88
#  pituitary_tumor       0.89      0.89      0.89       169
#
#         accuracy                           0.84       621
#        macro avg       0.83      0.84      0.83       621
#     weighted avg       0.84      0.84      0.84       621
#
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step
#
# Classification Report of Deeper Model with Adam Optimizer:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       1.00      0.49      0.65       181
# meningioma_tumor       0.64      0.65      0.64       183
#           normal       0.61      0.97      0.75        88
#  pituitary_tumor       0.78      0.95      0.86       169
#
#         accuracy                           0.73       621
#        macro avg       0.76      0.76      0.73       621
#     weighted avg       0.78      0.73      0.72       621
#
#
# Overall Performance Comparison:
#
#       Metric  Baseline      Adam
# 0   Accuracy  0.837359  0.729469
# 1  Precision  0.838275  0.777703
# 2     Recall  0.837359  0.729469
# 3   F1 Score  0.836911  0.719483
#
# Class-wise Metrics Comparison:
#
#                   Baseline Precision  Adam Precision  Baseline Recall  \
# glioma_tumor                0.847826        1.000000         0.861878
# meningioma_tumor            0.815476        0.639785         0.748634
# normal                      0.760000        0.607143         0.863636
# pituitary_tumor             0.893491        0.777778         0.893491
#
#                   Adam Recall  Baseline F1   Adam F1
# glioma_tumor         0.486188     0.854795  0.654275
# meningioma_tumor     0.650273     0.780627  0.644986
# normal               0.965909     0.808511  0.745614
# pituitary_tumor      0.952663     0.893491  0.856383

# %% [markdown]
# ## **Computational Efficiency**

# %%
comparison_df = pd.DataFrame({
    "Model": ["Baseline", "Deeper (Adam Optimizer)"],
    "Training Time (s)": [baseline_training_time, deeper1_training_time],
    "Total Parameters": [baseline_params, deeper1_params]
})

print("\nModel Training Time and Computational Cost Comparison:\n")
print(comparison_df)
# Out:
# Model Training Time and Computational Cost Comparison:
#
#                      Model  Training Time (s)  Total Parameters
# 0                 Baseline         256.171399           4298148
# 1  Deeper (Adam Optimizer)         408.970707           5806692

# %% [markdown]
# ## **Optimizer Analysis: SGD vs Adam**

# %% [markdown]
# ### **Deeper Model Architecture with SGD Optimizer**

# %%
# Define regularized deeper CNN model with SGD Optimizer
deeper2_model = keras.Sequential([
    # Block 1
    layers.Conv2D(32, (3, 3), padding="same", activation="relu", input_shape=(128, 128, 3)),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3, 3), padding="same", activation="relu"),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Block 2
    layers.Conv2D(64, (3, 3), padding="same", activation="relu"),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3, 3), padding="same", activation="relu"),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.3),

    # Block 3
    layers.Conv2D(128, (3, 3), padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3, 3), padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    # Block 4
    layers.Conv2D(256, (3, 3), padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Conv2D(256, (3, 3), padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.5),

    # Block 5
    layers.Conv2D(512, (3, 3), padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Conv2D(256, (3, 3), padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.6),

    # Block 6
    layers.Conv2D(1024, (3, 3), padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Conv2D(1024, (3, 3), padding="same", activation="relu", kernel_regularizer=regularizers.l2(0.001)),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.7),

    # Fully Connected Layers
    layers.Flatten(),

    # First FCN
    layers.Dense(512, activation="relu"),
    layers.Dropout(0.5),

    # Second FCN
    layers.Dense(256, activation="relu"),
    layers.Dropout(0.25),

    # Third FCN
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.2),

    #Fourth FCN
    layers.Dense(64, activation="relu"),
    layers.Dropout(0.1),

    # Fifth FCN
    layers.Dense(32, activation="relu"),

    #Output Layer
    layers.Dense(4, activation="softmax")  # 4 classes
])

# Define SGD optimizer with momentum
sgd = SGD(learning_rate=0.01, momentum=0.9)

# Compile the model
deeper2_model.compile(optimizer=sgd, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print model summary
deeper2_model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_13 (Conv2D)              │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 128, 128, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 64, 64, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_18 (Conv2D)              │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 8, 8, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 8, 8, 256)      │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 4, 4, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 4, 4, 1024)     │     2,360,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 4, 4, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (None, 4, 4, 1024)     │     9,438,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 2, 2, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 2, 2, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,611,268 (67.18 MB)
#  Trainable params: 17,607,236 (67.17 MB)
#  Non-trainable params: 4,032 (15.75 KB)

# %%
# Callbacks
checkpoint = ModelCheckpoint("best_model.h5", monitor='val_accuracy', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1, min_lr=1e-6)

# Train the model
deeper2_history = deeper2_model.fit(
    train_generator,
    epochs=50,
    validation_data=val_generator,
    callbacks=[checkpoint, early_stop, lr_reduce]
)
# Out:
# Epoch 1/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step - accuracy: 0.2767 - loss: 4.3788
# Epoch 1: val_accuracy improved from -inf to 0.39597, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 47s 381ms/step - accuracy: 0.2771 - loss: 4.3776 - val_accuracy: 0.3960 - val_loss: 4.3463 - learning_rate: 0.0100
# Epoch 2/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.3501 - loss: 4.1343
# Epoch 2: val_accuracy did not improve from 0.39597
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 155ms/step - accuracy: 0.3501 - loss: 4.1340 - val_accuracy: 0.2534 - val_loss: 4.1633 - learning_rate: 0.0100
# Epoch 3/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.3593 - loss: 4.0315
# Epoch 3: val_accuracy did not improve from 0.39597
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.3595 - loss: 4.0308 - val_accuracy: 0.2500 - val_loss: 4.1022 - learning_rate: 0.0100
# Epoch 4/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4004 - loss: 3.8804
# Epoch 4: val_accuracy did not improve from 0.39597
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 139ms/step - accuracy: 0.4008 - loss: 3.8799 - val_accuracy: 0.2500 - val_loss: 4.0644 - learning_rate: 0.0100
# Epoch 5/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.4325 - loss: 3.7806
# Epoch 5: val_accuracy did not improve from 0.39597
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 146ms/step - accuracy: 0.4323 - loss: 3.7804 - val_accuracy: 0.2500 - val_loss: 4.0226 - learning_rate: 0.0100
# Epoch 6/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3768 - loss: 3.7415
# Epoch 6: val_accuracy did not improve from 0.39597
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.3771 - loss: 3.7410 - val_accuracy: 0.2584 - val_loss: 3.9585 - learning_rate: 0.0100
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.4352 - loss: 3.6259
# Epoch 7: val_accuracy did not improve from 0.39597
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.4352 - loss: 3.6255 - val_accuracy: 0.3423 - val_loss: 3.7231 - learning_rate: 0.0100
# Epoch 8/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4419 - loss: 3.5166
# Epoch 8: val_accuracy did not improve from 0.39597
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 146ms/step - accuracy: 0.4420 - loss: 3.5163 - val_accuracy: 0.2567 - val_loss: 4.1567 - learning_rate: 0.0100
# Epoch 9/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5016 - loss: 3.4032
# Epoch 9: val_accuracy did not improve from 0.39597
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 146ms/step - accuracy: 0.5018 - loss: 3.4029 - val_accuracy: 0.3624 - val_loss: 3.8020 - learning_rate: 0.0100
# Epoch 10/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5429 - loss: 3.2787
# Epoch 10: val_accuracy improved from 0.39597 to 0.43121, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 154ms/step - accuracy: 0.5428 - loss: 3.2788 - val_accuracy: 0.4312 - val_loss: 3.3924 - learning_rate: 0.0100
# Epoch 11/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.5431 - loss: 3.2086
# Epoch 11: val_accuracy did not improve from 0.43121
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 145ms/step - accuracy: 0.5435 - loss: 3.2079 - val_accuracy: 0.2534 - val_loss: 6.2478 - learning_rate: 0.0100
# Epoch 12/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6053 - loss: 3.0524
# Epoch 12: val_accuracy did not improve from 0.43121
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - accuracy: 0.6053 - loss: 3.0523 - val_accuracy: 0.3339 - val_loss: 4.7005 - learning_rate: 0.0100
# Epoch 13/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.5972 - loss: 2.9788
# Epoch 13: val_accuracy improved from 0.43121 to 0.48490, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - accuracy: 0.5974 - loss: 2.9787 - val_accuracy: 0.4849 - val_loss: 3.2003 - learning_rate: 0.0100
# Epoch 14/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6085 - loss: 2.9045
# Epoch 14: val_accuracy did not improve from 0.48490
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 20s 148ms/step - accuracy: 0.6088 - loss: 2.9041 - val_accuracy: 0.4581 - val_loss: 3.1497 - learning_rate: 0.0100
# Epoch 15/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.6212 - loss: 2.8516
# Epoch 15: val_accuracy did not improve from 0.48490
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 20s 144ms/step - accuracy: 0.6213 - loss: 2.8512 - val_accuracy: 0.4715 - val_loss: 3.3046 - learning_rate: 0.0100
# Epoch 16/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6423 - loss: 2.7282
# Epoch 16: val_accuracy did not improve from 0.48490
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.6420 - loss: 2.7286 - val_accuracy: 0.2601 - val_loss: 5.6914 - learning_rate: 0.0100
# Epoch 17/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6530 - loss: 2.6805
# Epoch 17: val_accuracy did not improve from 0.48490
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 147ms/step - accuracy: 0.6528 - loss: 2.6806 - val_accuracy: 0.3507 - val_loss: 3.6207 - learning_rate: 0.0100
# Epoch 18/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6675 - loss: 2.6344
# Epoch 18: val_accuracy improved from 0.48490 to 0.48826, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 156ms/step - accuracy: 0.6676 - loss: 2.6339 - val_accuracy: 0.4883 - val_loss: 3.2772 - learning_rate: 0.0050
# Epoch 19/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.6622 - loss: 2.5603
# Epoch 19: val_accuracy did not improve from 0.48826
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 157ms/step - accuracy: 0.6627 - loss: 2.5595 - val_accuracy: 0.4161 - val_loss: 3.7686 - learning_rate: 0.0050
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 14.

# %%
# Plot training vs validation loss
plt.figure(figsize=(12, 4))

# Plotting training and validation loss
plt.subplot(1, 2, 1)
plt.plot(deeper2_history.history['loss'], label='Training Loss')
plt.plot(deeper2_history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss for Deeper Model with SGD')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plotting Training and Validation Accuracy
plt.subplot(1, 2, 2)
plt.plot(deeper2_history.history['accuracy'], label='Training Accuracy')
plt.plot(deeper2_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy for Deeper Model with SGD')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Evaluate the model on the test data
test_loss, test_accuracy = deeper2_model.evaluate(test_generator)
print(f"\nTest Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 204ms/step - accuracy: 0.5512 - loss: 3.0707
#
# Test Accuracy: 0.4203
# Test Loss: 3.1601

# %%
# Get true labels
true_labels = test_generator.classes

# Get predicted probabilities and convert to class labels
pred_probs = deeper2_model.predict(test_generator)
pred_labels = np.argmax(pred_probs, axis=1)

# Calculate metrics
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, average='weighted')
recall = recall_score(true_labels, pred_labels, average='weighted')
f1 = f1_score(true_labels, pred_labels, average='weighted')

print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")

class_labels = list(test_generator.class_indices.keys())
deep2_report = classification_report(true_labels, pred_labels, target_names=class_labels)
print("\nClassification Report of Deeper Model with SGD Optimizer:\n")
print(deep2_report)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step
# Accuracy:  0.4203
# Precision: 0.4604
# Recall:    0.4203
# F1 Score:  0.3866
#
# Classification Report of Deeper Model with SGD Optimizer:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.34      0.77      0.47       181
# meningioma_tumor       0.27      0.08      0.13       183
#           normal       0.69      0.33      0.45        88
#  pituitary_tumor       0.68      0.46      0.54       169
#
#         accuracy                           0.42       621
#        macro avg       0.49      0.41      0.40       621
#     weighted avg       0.46      0.42      0.39       621

# %%
# Define class labels
class_labels = list(test_generator.class_indices.keys())

# Sample a few test images
sample_images = []
true_classes = []
for class_name in class_labels:
    class_dir = os.path.join(test_dir, class_name)
    images = os.listdir(class_dir)[:2]  # 2 images per class
    for img_name in images:
        sample_images.append(os.path.join(class_dir, img_name))
        true_classes.append(class_name)

# Plot predictions
plt.figure(figsize=(15, 10))

for i, img_path in enumerate(sample_images):
    # Load image
    img = load_img(img_path, target_size=(128, 128))
    img_array = img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    # Predict
    predictions = deeper2_model.predict(img_array)
    predicted_class = class_labels[np.argmax(predictions)]
    true_class = true_classes[i]

    # Color: green if correct, red otherwise
    color = "green" if predicted_class == true_class else "red"

    # Plot
    plt.subplot(3, 4, i + 1)
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"True: {true_class}\nPred: {predicted_class}", color=color)

plt.tight_layout()
plt.suptitle("Prediction of different Classes with Deeper Model and SGD Optimizer", fontsize=16, y=1.02)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %% [markdown]
# ### **Comparison Between Adam and SGD Optimizer**

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import pandas as pd

# Get true labels
true_labels = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# Function to evaluate model
def evaluate_model(model, model_name):
    pred_probs = model.predict(test_generator)
    pred_labels = np.argmax(pred_probs, axis=1)

    accuracy = accuracy_score(true_labels, pred_labels)
    precision = precision_score(true_labels, pred_labels, average='weighted')
    recall = recall_score(true_labels, pred_labels, average='weighted')
    f1 = f1_score(true_labels, pred_labels, average='weighted')

    report = classification_report(true_labels, pred_labels, target_names=class_labels, output_dict=True)

    print(f"\nClassification Report of {model_name}:\n")
    print(classification_report(true_labels, pred_labels, target_names=class_labels))

    return {
        "Model": model_name,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1 Score": f1,
        "Report": report
    }

# Evaluate both models
results_adam = evaluate_model(deeper1_model, "Deeper Model with Adam Optimizer")
results_sgd = evaluate_model(deeper2_model, "Deeper Model with SGD Optimizer")

# Compare overall metrics
overall_comparison = pd.DataFrame([
    {"Metric": "Accuracy", "Adam": results_adam["Accuracy"], "SGD": results_sgd["Accuracy"]},
    {"Metric": "Precision", "Adam": results_adam["Precision"], "SGD": results_sgd["Precision"]},
    {"Metric": "Recall", "Adam": results_adam["Recall"], "SGD": results_sgd["Recall"]},
    {"Metric": "F1 Score", "Adam": results_adam["F1 Score"], "SGD": results_sgd["F1 Score"]}
])

print("\nOverall Performance Comparison:\n")
print(overall_comparison)

# Class-wise comparison
class_comparison = pd.DataFrame({
    cls: {
        "Adam Precision": results_adam["Report"][cls]["precision"],
        "SGD Precision": results_sgd["Report"][cls]["precision"],
        "Adam Recall": results_adam["Report"][cls]["recall"],
        "SGD Recall": results_sgd["Report"][cls]["recall"],
        "Adam F1": results_adam["Report"][cls]["f1-score"],
        "SGD F1": results_sgd["Report"][cls]["f1-score"]
    }
    for cls in class_labels
}).T

print("\nClass-wise Metrics Comparison:\n")
print(class_comparison)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
#
# Classification Report of Deeper Model with Adam Optimizer:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       1.00      0.49      0.65       181
# meningioma_tumor       0.64      0.65      0.64       183
#           normal       0.61      0.97      0.75        88
#  pituitary_tumor       0.78      0.95      0.86       169
#
#         accuracy                           0.73       621
#        macro avg       0.76      0.76      0.73       621
#     weighted avg       0.78      0.73      0.72       621
#
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
#
# Classification Report of Deeper Model with SGD Optimizer:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.34      0.77      0.47       181
# meningioma_tumor       0.27      0.08      0.13       183
#           normal       0.69      0.33      0.45        88
#  pituitary_tumor       0.68      0.46      0.54       169
#
#         accuracy                           0.42       621
#        macro avg       0.49      0.41      0.40       621
#     weighted avg       0.46      0.42      0.39       621
#
#
# Overall Performance Comparison:
#
#       Metric      Adam       SGD
# 0   Accuracy  0.729469  0.420290
# 1  Precision  0.777703  0.460362
# 2     Recall  0.729469  0.420290
# 3   F1 Score  0.719483  0.386627
#
# Class-wise Metrics Comparison:
#
#                   Adam Precision  SGD Precision  Adam Recall  SGD Recall  \
# glioma_tumor            1.000000       0.342298     0.486188    0.773481
# meningioma_tumor        0.639785       0.267857     0.650273    0.081967
# normal                  0.607143       0.690476     0.965909    0.329545
# pituitary_tumor         0.777778       0.675439     0.952663    0.455621
#
#                    Adam F1    SGD F1
# glioma_tumor      0.654275  0.474576
# meningioma_tumor  0.644986  0.125523
# normal            0.745614  0.446154
# pituitary_tumor   0.856383  0.544170

# %% [markdown]
# # **Part B: Fine-Tuning a Pre-Trained Model (Transfer Learning)**

# %% [markdown]
# ## **ResNet50 Pretrained Model**

# %%
# Load pre-trained ResNet50 base (exclude top FC layers)
resnet_base = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(128, 128, 3)
)

# Freeze base layers
resnet_base.trainable = False

# Build the new model
transfer_model = models.Sequential([
    resnet_base,

    # Feature extraction output (from ResNet)
    layers.BatchNormalization(),
    layers.GlobalAveragePooling2D(),

    # Custom FC layers (deeper version)
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),

    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),

    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),

    layers.Dense(64, activation='relu'),

    # Output layer
    layers.Dense(4, activation='softmax')  # 4 output classes
])

# Compile model
transfer_model.compile(
    optimizer=keras.optimizers.Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Show summary
transfer_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 4, 4, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 4, 4, 2048)     │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,817,732 (94.67 MB)
#  Trainable params: 1,225,924 (4.68 MB)
#  Non-trainable params: 23,591,808 (90.00 MB)

# %%
# Early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
transfer_history = transfer_model.fit(
    train_generator,
    epochs=50,
    validation_data=val_generator,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 39s 334ms/step - accuracy: 0.3745 - loss: 1.2788 - val_accuracy: 0.3087 - val_loss: 1.4266
# Epoch 2/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.5726 - loss: 1.0194 - val_accuracy: 0.2685 - val_loss: 1.6393
# Epoch 3/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 154ms/step - accuracy: 0.6561 - loss: 0.8236 - val_accuracy: 0.4195 - val_loss: 1.4108
# Epoch 4/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.6927 - loss: 0.7828 - val_accuracy: 0.4648 - val_loss: 1.1668
# Epoch 5/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 20s 149ms/step - accuracy: 0.7227 - loss: 0.7168 - val_accuracy: 0.5302 - val_loss: 1.1505
# Epoch 6/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.7476 - loss: 0.6647 - val_accuracy: 0.5554 - val_loss: 1.0633
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.7478 - loss: 0.6372 - val_accuracy: 0.6829 - val_loss: 0.9392
# Epoch 8/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.7815 - loss: 0.5610 - val_accuracy: 0.6275 - val_loss: 1.1009
# Epoch 9/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.7734 - loss: 0.5897 - val_accuracy: 0.6309 - val_loss: 1.1736
# Epoch 10/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 151ms/step - accuracy: 0.7819 - loss: 0.5280 - val_accuracy: 0.6544 - val_loss: 1.1347
# Epoch 11/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - accuracy: 0.8079 - loss: 0.5210 - val_accuracy: 0.6846 - val_loss: 1.0738
# Epoch 12/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 151ms/step - accuracy: 0.8188 - loss: 0.4457 - val_accuracy: 0.7047 - val_loss: 1.0507

# %%
# Plot training vs validation loss
plt.figure(figsize=(12, 4))

# Plotting training and validation loss
plt.subplot(1, 2, 1)
plt.plot(transfer_history.history['loss'], label='Training Loss')
plt.plot(transfer_history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss for Deeper Model with Adam')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plotting Training and Validation Accuracy
plt.subplot(1, 2, 2)
plt.plot(transfer_history.history['accuracy'], label='Training Accuracy')
plt.plot(transfer_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy for Transfer Model as ResNet50')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.show()

# %%
# Evaluate the model on the test data
test_loss, test_accuracy = transfer_model.evaluate(test_generator)
print(f"\nTest Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 249ms/step - accuracy: 0.6959 - loss: 0.8191
#
# Test Accuracy: 0.7343
# Test Loss: 0.7239

# %%
# Get true labels
true_labels = test_generator.classes

# Get predicted probabilities and convert to class labels
pred_probs = transfer_model.predict(test_generator)
pred_labels = np.argmax(pred_probs, axis=1)

# Calculate metrics
accuracy = accuracy_score(true_labels, pred_labels)
precision = precision_score(true_labels, pred_labels, average='weighted')
recall = recall_score(true_labels, pred_labels, average='weighted')
f1 = f1_score(true_labels, pred_labels, average='weighted')

print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")

class_labels = list(test_generator.class_indices.keys())
transfer_report = classification_report(true_labels, pred_labels, target_names=class_labels)
print("\nClassification Report of Transfer Model as ResNet50:\n")
print(transfer_report)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 10s 290ms/step
# Accuracy:  0.7343
# Precision: 0.7324
# Recall:    0.7343
# F1 Score:  0.7321
#
# Classification Report of Transfer Model as ResNet50:
#
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.72      0.71      0.71       181
# meningioma_tumor       0.70      0.62      0.66       183
#           normal       0.72      0.81      0.76        88
#  pituitary_tumor       0.79      0.85      0.82       169
#
#         accuracy                           0.73       621
#        macro avg       0.73      0.75      0.74       621
#     weighted avg       0.73      0.73      0.73       621

# %%
# Define class labels
class_labels = list(test_generator.class_indices.keys())

# Sample a few test images
sample_images = []
true_classes = []
for class_name in class_labels:
    class_dir = os.path.join(test_dir, class_name)
    images = os.listdir(class_dir)[:2]  # 2 images per class
    for img_name in images:
        sample_images.append(os.path.join(class_dir, img_name))
        true_classes.append(class_name)

# Plot predictions
plt.figure(figsize=(15, 10))

for i, img_path in enumerate(sample_images):
    # Load image
    img = load_img(img_path, target_size=(128, 128))
    img_array = img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    # Predict
    predictions = transfer_model.predict(img_array)
    predicted_class = class_labels[np.argmax(predictions)]
    true_class = true_classes[i]

    # Color: green if correct, red otherwise
    color = "green" if predicted_class == true_class else "red"

    # Plot
    plt.subplot(3, 4, i + 1)
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"True: {true_class}\nPred: {predicted_class}", color=color)

plt.tight_layout()
plt.suptitle("Prediction of different Classes with Transfer Model ResNet50", fontsize=16, y=1.02)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
